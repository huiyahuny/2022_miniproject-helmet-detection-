# %%
import numpy as np

# %%
import pandas as pd

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import keras

# %%
import cvlib as cv

# %%
import os

non_list = os.listdir('C:/K_digital/Source/helmet/helmet_n')
print(non_list)

yes_list = os.listdir('C:/K_digital/Source/helmet/helmet_y')
print(yes_list)
# Out:
# ['helmetn1.jpg', 'helmetn10.jpg', 'helmetn100.jpg', 'helmetn101.jpg', 'helmetn102.jpg', 'helmetn103.jpg', 'helmetn104.jpg', 'helmetn105.jpg', 'helmetn106.jpg', 'helmetn107.jpg', 'helmetn108.jpg', 'helmetn109.jpg', 'helmetn11.jpg', 'helmetn110.jpg', 'helmetn111.jpg', 'helmetn112.jpg', 'helmetn113.jpg', 'helmetn114.jpg', 'helmetn115.jpg', 'helmetn116.jpg', 'helmetn117.jpg', 'helmetn118.jpg', 'helmetn119.jpg', 'helmetn12.jpg', 'helmetn120.jpg', 'helmetn121.jpg', 'helmetn122.jpg', 'helmetn123.jpg', 'helmetn124.jpg', 'helmetn125.jpg', 'helmetn126.jpg', 'helmetn127.jpg', 'helmetn128.jpg', 'helmetn129.jpg', 'helmetn13.jpg', 'helmetn130.jpg', 'helmetn131.jpg', 'helmetn132.jpg', 'helmetn133.jpg', 'helmetn134.jpg', 'helmetn135.jpg', 'helmetn136.jpg', 'helmetn137.jpg', 'helmetn138.jpg', 'helmetn139.jpg', 'helmetn14.jpg', 'helmetn140.jpg', 'helmetn141.jpg', 'helmetn142.jpg', 'helmetn143.jpg', 'helmetn144.jpg', 'helmetn145.jpg', 'helmetn146.jpg', 'helmetn147.jpg', 'helmetn148.jpg', 'helmetn149.jpg', 'helmetn15.jpg', 'helmetn150.jpg', 'helmetn151.jpg', 'helmetn152.jpg', 'helmetn153.jpg', 'helmetn154.jpg', 'helmetn155.jpg', 'helmetn156.jpg', 'helmetn157.jpg', 'helmetn158.jpg', 'helmetn159.jpg', 'helmetn16.jpg', 'helmetn160.jpg', 'helmetn161.jpg', 'helmetn162.jpg', 'helmetn163.jpg', 'helmetn164.jpg', 'helmetn165.jpg', 'helmetn166.jpg', 'helmetn167.jpg', 'helmetn168.jpg', 'helmetn169.jpg', 'helmetn17.jpg', 'helmetn170.jpg', 'helmetn171.jpg', 'helmetn172.jpg', 'helmetn173.jpg', 'helmetn174.jpg', 'helmetn175.jpg', 'helmetn176.jpg', 'helmetn177.jpg', 'helmetn178.jpg', 'helmetn179.jpg', 'helmetn18.jpg', 'helmetn180.jpg', 'helmetn181.jpg', 'helmetn182.jpg', 'helmetn183.jpg', 'helmetn184.jpg', 'helmetn185.jpg', 'helmetn186.jpg', 'helmetn187.jpg', 'helmetn188.jpg', 'helmetn189.jpg', 'helmetn19.jpg', 'helmetn190.jpg', 'helmetn191.jpg', 'helmetn192.jpg', 'helmetn193.jpg', 'helmetn194.jpg', 'helmetn195.jpg', 'helmetn196.jpg', 'helmetn197.jpg', 'helmetn198.jpg', 'helmetn199.jpg', 'helmetn2.jpg', 'helmetn20.jpg', 'helmetn200.jpg', 'helmetn201.jpg', 'helmetn202.jpg', 'helmetn203.jpg', 'helmetn204.jpg', 'helmetn205.jpg', 'helmetn206.jpg', 'helmetn207.jpg', 'helmetn208.jpg', 'helmetn209.jpg', 'helmetn21.jpg', 'helmetn210.jpg', 'helmetn211.jpg', 'helmetn212.jpg', 'helmetn213.jpg', 'helmetn214.jpg', 'helmetn215.jpg', 'helmetn216.jpg', 'helmetn217.jpg', 'helmetn218.jpg', 'helmetn219.jpg', 'helmetn22.jpg', 'helmetn220.jpg', 'helmetn221.jpg', 'helmetn222.jpg', 'helmetn223.jpg', 'helmetn224.jpg', 'helmetn225.jpg', 'helmetn226.jpg', 'helmetn227.jpg', 'helmetn228.jpg', 'helmetn229.jpg', 'helmetn23.jpg', 'helmetn230.jpg', 'helmetn231.jpg', 'helmetn232.jpg', 'helmetn233.jpg', 'helmetn234.jpg', 'helmetn235.jpg', 'helmetn236.jpg', 'helmetn237.jpg', 'helmetn238.jpg', 'helmetn239.jpg', 'helmetn24.jpg', 'helmetn240.jpg', 'helmetn241.jpg', 'helmetn242.jpg', 'helmetn243.jpg', 'helmetn244.jpg', 'helmetn245.jpg', 'helmetn246.jpg', 'helmetn247.jpg', 'helmetn248.jpg', 'helmetn249.jpg', 'helmetn25.jpg', 'helmetn250.jpg', 'helmetn251.jpg', 'helmetn252.jpg', 'helmetn253.jpg', 'helmetn254.jpg', 'helmetn255.jpg', 'helmetn256.jpg', 'helmetn257.jpg', 'helmetn258.jpg', 'helmetn259.jpg', 'helmetn26.jpg', 'helmetn260.jpg', 'helmetn261.jpg', 'helmetn262.jpg', 'helmetn263.jpg', 'helmetn264.jpg', 'helmetn265.jpg', 'helmetn266.jpg', 'helmetn267.jpg', 'helmetn268.jpg', 'helmetn269.jpg', 'helmetn27.jpg', 'helmetn270.jpg', 'helmetn271.jpg', 'helmetn272.jpg', 'helmetn273.jpg', 'helmetn274.jpg', 'helmetn275.jpg', 'helmetn276.jpg', 'helmetn277.jpg', 'helmetn278.jpg', 'helmetn279.jpg', 'helmetn28.jpg', 'helmetn280.jpg', 'helmetn281.jpg', 'helmetn282.jpg', 'helmetn283.jpg', 'helmetn284.jpg', 'helmetn285.jpg', 'helmetn286.jpg', 'helmetn287.jpg', 'helmetn288.jpg', 'helmetn289.jpg', 'helmetn29.jpg', 'helmetn290.jpg', 'helmetn291.jpg', 'helmetn292.jpg', 'helmetn293.jpg', 'helmetn294.jpg', 'helmetn295.jpg', 'helmetn296.jpg', 'helmetn297.jpg', 'helmetn298.jpg', 'helmetn299.jpg', 'helmetn3.jpg', 'helmetn30. ...
# ['helmety1.jpg', 'helmety10.jpg', 'helmety100.jpg', 'helmety101.jpg', 'helmety102.jpg', 'helmety103.jpg', 'helmety104.jpg', 'helmety105.jpg', 'helmety106.jpg', 'helmety107.jpg', 'helmety108.jpg', 'helmety109.jpg', 'helmety11.jpg', 'helmety110.jpg', 'helmety111.jpg', 'helmety112.jpg', 'helmety113.jpg', 'helmety114.jpg', 'helmety115.jpg', 'helmety116.jpg', 'helmety117.jpg', 'helmety118.jpg', 'helmety119.jpg', 'helmety12.jpg', 'helmety120.jpg', 'helmety121.jpg', 'helmety122.jpg', 'helmety123.jpg', 'helmety124.jpg', 'helmety125.jpg', 'helmety126.jpg', 'helmety127.jpg', 'helmety128.jpg', 'helmety129.jpg', 'helmety13.jpg', 'helmety130.jpg', 'helmety131.jpg', 'helmety132.jpg', 'helmety133.jpg', 'helmety134.jpg', 'helmety135.jpg', 'helmety136.jpg', 'helmety137.jpg', 'helmety138.jpg', 'helmety139.jpg', 'helmety14.jpg', 'helmety140.jpg', 'helmety141.jpg', 'helmety142.jpg', 'helmety143.jpg', 'helmety144.jpg', 'helmety145.jpg', 'helmety146.jpg', 'helmety147.jpg', 'helmety148.jpg', 'helmety149.jpg', 'helmety15.jpg', 'helmety150.jpg', 'helmety151.jpg', 'helmety152.jpg', 'helmety153.jpg', 'helmety154.jpg', 'helmety155.jpg', 'helmety156.jpg', 'helmety157.jpg', 'helmety158.jpg', 'helmety159.jpg', 'helmety16.jpg', 'helmety160.jpg', 'helmety161.jpg', 'helmety162.jpg', 'helmety163.jpg', 'helmety164.jpg', 'helmety165.jpg', 'helmety166.jpg', 'helmety167.jpg', 'helmety168.jpg', 'helmety169.jpg', 'helmety17.jpg', 'helmety170.jpg', 'helmety171.jpg', 'helmety172.jpg', 'helmety173.jpg', 'helmety174.jpg', 'helmety175.jpg', 'helmety176.jpg', 'helmety177.jpg', 'helmety178.jpg', 'helmety179.jpg', 'helmety18.jpg', 'helmety180.jpg', 'helmety181.jpg', 'helmety182.jpg', 'helmety183.jpg', 'helmety184.jpg', 'helmety185.jpg', 'helmety186.jpg', 'helmety187.jpg', 'helmety188.jpg', 'helmety189.jpg', 'helmety19.jpg', 'helmety190.jpg', 'helmety191.jpg', 'helmety192.jpg', 'helmety193.jpg', 'helmety194.jpg', 'helmety195.jpg', 'helmety196.jpg', 'helmety197.jpg', 'helmety198.jpg', 'helmety199.jpg', 'helmety2.jpg', 'helmety20.jpg', 'helmety200.jpg', 'helmety201.jpg', 'helmety202.jpg', 'helmety203.jpg', 'helmety204.jpg', 'helmety205.jpg', 'helmety206.jpg', 'helmety207.jpg', 'helmety208.jpg', 'helmety209.jpg', 'helmety21.jpg', 'helmety210.jpg', 'helmety211.jpg', 'helmety212.jpg', 'helmety213.jpg', 'helmety214.jpg', 'helmety215.jpg', 'helmety216.jpg', 'helmety217.jpg', 'helmety218.jpg', 'helmety219.jpg', 'helmety22.jpg', 'helmety220.jpg', 'helmety221.jpg', 'helmety222.jpg', 'helmety223.jpg', 'helmety224.jpg', 'helmety225.jpg', 'helmety226.jpg', 'helmety227.jpg', 'helmety228.jpg', 'helmety229.jpg', 'helmety23.jpg', 'helmety230.jpg', 'helmety231.jpg', 'helmety232.jpg', 'helmety233.jpg', 'helmety234.jpg', 'helmety235.jpg', 'helmety236.jpg', 'helmety237.jpg', 'helmety238.jpg', 'helmety239.jpg', 'helmety24.jpg', 'helmety240.jpg', 'helmety241.jpg', 'helmety242.jpg', 'helmety243.jpg', 'helmety244.jpg', 'helmety245.jpg', 'helmety246.jpg', 'helmety247.jpg', 'helmety248.jpg', 'helmety249.jpg', 'helmety25.jpg', 'helmety250.jpg', 'helmety251.jpg', 'helmety252.jpg', 'helmety253.jpg', 'helmety254.jpg', 'helmety255.jpg', 'helmety256.jpg', 'helmety257.jpg', 'helmety258.jpg', 'helmety259.jpg', 'helmety26.jpg', 'helmety260.jpg', 'helmety261.jpg', 'helmety262.jpg', 'helmety263.jpg', 'helmety264.jpg', 'helmety265.jpg', 'helmety266.jpg', 'helmety267.jpg', 'helmety268.jpg', 'helmety269.jpg', 'helmety27.jpg', 'helmety270.jpg', 'helmety271.jpg', 'helmety272.jpg', 'helmety273.jpg', 'helmety274.jpg', 'helmety275.jpg', 'helmety276.jpg', 'helmety277.jpg', 'helmety278.jpg', 'helmety279.jpg', 'helmety28.jpg', 'helmety280.jpg', 'helmety281.jpg', 'helmety282.jpg', 'helmety283.jpg', 'helmety284.jpg', 'helmety285.jpg', 'helmety286.jpg', 'helmety287.jpg', 'helmety288.jpg', 'helmety289.jpg', 'helmety29.jpg', 'helmety290.jpg', 'helmety291.jpg', 'helmety292.jpg', 'helmety293.jpg', 'helmety294.jpg', 'helmety295.jpg', 'helmety296.jpg', 'helmety297.jpg', 'helmety298.jpg', 'helmety299.jpg', 'helmety3.jpg', 'helmety30. ...

# %%
import cv2

# %%
image = cv2.imread('C:/K_digital/Source/helmet/helmet_n/'+'helmetn99.jpg')
image.shape
#(354, 458, 3)
# Out:
# (240, 232, 3)

# %%
image.shape
# Out:
# (240, 232, 3)

# %%
for i in non_list:
    print(i)
    img = cv2.imread('C:/K_digital/Source/helmet/helmet_n/' + i)
    print(img.shape)
# Out:
# helmetn1.jpg
# (240, 240, 3)
# helmetn10.jpg
# (238, 240, 3)
# helmetn100.jpg
# (240, 234, 3)
# helmetn101.jpg
# (240, 234, 3)
# helmetn102.jpg
# (240, 238, 3)
# helmetn103.jpg
# (240, 240, 3)
# helmetn104.jpg
# (248, 240, 3)
# helmetn105.jpg
# (236, 238, 3)
# helmetn106.jpg
# (236, 240, 3)
# helmetn107.jpg
# (236, 242, 3)
# helmetn108.jpg
# (236, 234, 3)
# helmetn109.jpg
# (238, 238, 3)
# helmetn11.jpg
# (238, 232, 3)
# helmetn110.jpg
# (232, 240, 3)
# helmetn111.jpg
# (238, 240, 3)
# helmetn112.jpg
# (238, 242, 3)
# helmetn113.jpg
# (232, 234, 3)
# helmetn114.jpg
# (240, 242, 3)
# helmetn115.jpg
# (238, 238, 3)
# helmetn116.jpg
# (236, 240, 3)
# helmetn117.jpg
# (238, 240, 3)
# helmetn118.jpg
# (236, 242, 3)
# helmetn119.jpg
# (238, 246, 3)
# helmetn12.jpg
# (238, 234, 3)
# helmetn120.jpg
# (246, 238, 3)
# helmetn121.jpg
# (242, 240, 3)
# helmetn122.jpg
# (246, 240, 3)
# helmetn123.jpg
# (242, 242, 3)
# helmetn124.jpg
# (242, 234, 3)
# helmetn125.jpg
# (240, 234, 3)
# helmetn126.jpg
# (238, 238, 3)
# helmetn127.jpg
# (238, 240, 3)
# helmetn128.jpg
# (238, 240, 3)
# helmetn129.jpg
# (238, 242, 3)
# helmetn13.jpg
# (246, 240, 3)
# helmetn130.jpg
# (238, 234, 3)
# helmetn131.jpg
# (238, 238, 3)
# helmetn132.jpg
# (238, 240, 3)
# helmetn133.jpg
# (238, 240, 3)
# helmetn134.jpg
# (238, 242, 3)
# helmetn135.jpg
# (238, 234, 3)
# helmetn136.jpg
# (240, 238, 3)
# helmetn137.jpg
# (242, 240, 3)
# helmetn138.jpg
# (242, 240, 3)
# helmetn139.jpg
# (242, 234, 3)
# helmetn14.jpg
# (234, 238, 3)
# helmetn140.jpg
# (238, 238, 3)
# helmetn141.jpg
# (238, 242, 3)
# helmetn142.jpg
# (640, 685, 3)
# helmetn143.jpg
# (1280, 1920, 3)
# helmetn144.jpg
# (549, 563, 3)
# helmetn145.jpg
# (1872, 1872, 3)
# helmetn146.jpg
# (239, 237, 3)
# helmetn147.jpg
# (240, 240, 3)
# helmetn148.jpg
# (373, 545, 3)
# helmetn149.jpg
# (243, 242, 3)
# helmetn15.jpg
# (234, 240, 3)
# helmetn150.jpg
# (240, 238, 3)
# helmetn151.jpg
# (1281, 1920, 3)
# helmetn152.jpg
# (1440, 1920, 3)
# helmetn153.jpg
# (591, 884, 3)
# helmetn154.jpg
# (568, 371, 3)
# helmetn155.jpg
# (586, 883, 3)
# helmetn156.jpg
# (466, 700, 3)
# helmetn157.jpg
# (563, 617, 3)
# helmetn158.jpg
# (240, 240, 3)
# helmetn159.jpg
# (801, 1200, 3)
# helmetn16.jpg
# (234, 240, 3)
# helmetn160.jpg
# (711, 799, 3)
# helmetn161.jpg
# (1350, 1080, 3)
# helmetn162.jpg
# (315, 209, 3)
# helmetn163.jpg
# (651, 503, 3)
# helmetn164.jpg
# (512, 894, 3)
# helmetn165.jpg
# (632, 630, 3)
# helmetn166.jpg
# (717, 539, 3)
# helmetn167.jpg
# (274, 194, 3)
# helmetn168.jpg
# (630, 420, 3)
# helmetn169.jpg
# (240, 242, 3)
# helmetn17.jpg
# (234, 232, 3)
# helmetn170.jpg
# (1280, 1920, 3)
# helmetn171.jpg
# (1920, 1280, 3)
# helmetn172.jpg
# (717, 725, 3)
# helmetn173.jpg
# (1280, 1920, 3)
# helmetn174.jpg
# (1293, 1920, 3)
# helmetn175.jpg
# (1272, 1920, 3)
# helmetn176.jpg
# (243, 243, 3)
# helmetn177.jpg
# (1920, 1384, 3)
# helmetn178.jpg
# (591, 476, 3)
# helmetn179.jpg
# (262, 400, 3)
# helmetn18.jpg
# (234, 234, 3)
# helmetn180.jpg
# (240, 234, 3)
# helmetn181.jpg
# (1282, 1920, 3)
# helmetn182.jpg
# (1280, 1920, 3)
# helmetn183.jpg
# (1280, 1920, 3)
# helmetn184.jpg
# (251, 201, 3)
# helmetn185.jpg
# (242, 232, 3)
# helmetn186.jpg
# (241, 238, 3)
# helmetn187.jpg
# (242, 234, 3)
# helmetn188.jpg
# (240, 238, 3)
# helmetn189.jpg
# (241, 238, 3)
# helmetn19.jpg
# (242, 238, 3)
# helmetn190.jpg
# (240, 238, 3)
# helmetn191.jpg
# (397, 375, 3)
# helmetn192.jpg
# (425, 441, 3)
# helmetn193.jpg
# (425, 612, 3)
# helmetn194.jpg
# (1300, 866, 3)
# helmetn195.jpg
# (1000, 1500, 3)
# helmetn196.jpg
# (866, 1300, 3)
# helmetn197.jpg
# (417, 626, 3)
# helmetn198.jpg
# (544, 540, 3)
# helmetn199.jpg
# (273, 185, 3)
# helmetn2.jpg
# (246, 238, 3)
# helmetn20.jpg
# (242, 240, 3)
# helmetn200.jpg
# (1024, 786, 3)
# helmetn201.jpg
# (417, 626, 3)
# helmetn202.jpg
# (182, 278, 3)
# helmetn203.jpg
# (523, 539, 3)
# helmetn204.jpg
# (668, 1000, 3)
# helmetn205.jpg
# (1300, 866, 3)
# helmetn206.jpg
# (183, 275, 3)
# helmetn207.jpg
# (280, 390, 3)
# helmetn208.jpg
# (183, 275, 3)
# helmetn209.jpg
# (280, 389, 3)
# helmetn21.jpg
# (240, 240, 3)
# helmetn210.jpg
# (183, 275, 3)
# helmetn211.jpg
# (750, 500, 3)
# helmetn212.jpg
# (845, 1500, 3)
# helmetn213.jpg
# (1350, 1080, 3)
# helmetn214.jpg
# (476, 460, 3)
# helmetn215.jpg
# (377, 600, 3)
# helmetn216.jpg
# (600, 400, 3)
# helmetn217.jpg
# (597, 480, 3)
# helmetn218.jpg
# (275, 183, 3)
# helmetn219.jpg
# (183, 275, 3)
# helmetn22.jpg
# (240, 232, 3)
# helmetn220.jpg
# (183, 275, 3)
# helmetn221.jpg
# (1243, 1600, 3)
# helmetn222.jpg
# (251, 201, 3)
# helmetn223.jpg
# (700, 466, 3)
# helmetn224.jpg
# (446, 477, 3)
# helmetn225.jpg
# (417, 626, 3)
# helmetn226.jpg
# (594, 540, 3)
# helmetn227.jpg
# (482, 700, 3)
# helmetn228.jpg
# (450, 800, 3)
# helmetn229.jpg
# (478, 500, 3)
# helmetn23.jpg
# (240, 234, 3)
# helmetn230.jpg
# (252, 200, 3)
# helmetn231.jpg
# (583, 530, 3)
# helmetn232.jpg
# (755, 520, 3)
# helmetn233.jpg
# (769, 600, 3)
# helmetn234.jpg
# (435, 688, 3)
# helmetn235.jpg
# (866, 1300, 3)
# helmetn236.jpg
# (750, 500, 3)
# helmetn237.jpg
# (251, 201, 3)
# helmetn238.jpg
# (225, 225, 3)
# helmetn239.jpg
# (183, 275, 3)
# helmetn24.jpg
# (246, 240, 3)
# helmetn240.jpg
# (262, 192, 3)
# helmetn241.jpg
# (932, 746, 3)
# helmetn242.jpg
# (264, 191, 3)
# helmetn243.jpg
# (538, 960, 3)
# helmetn244.jpg
# (780, 780, 3)
# helmetn245.jpg
# (1067, 800, 3)
# helmetn246.jpg
# (588, 782, 3)
# helmetn247.jpg
# (675, 675, 3)
# helmetn248.jpg
# (262, 192, 3)
# helmetn249.jpg
# (500, 500, 3)
# helmetn25.jpg
# (238, 238, 3)
# helmetn250.jpg
# (800, 800, 3)
# helmetn251.jpg
# (259, 195, 3)
# helmetn252.jpg
# (737, 1000, 3)
# helmetn253.jpg
# (717, 778, 3)
# helmetn254.jpg
# (800, 1200, 3)
# helmetn255.jpg
# (599, 600, 3)
# helmetn256.jpg
# (225, 225, 3)
# helmetn257.jpg
# (224, 224, 3)
# helmetn258.jpg
# (360, 360, 3)
# helmetn259.jpg
# (225, 225, 3)
# helmetn26.jpg
# (238, 240, 3)
# helmetn260.jpg
# (1000, 860, 3)
# helmetn261.jpg
# (199, 253, 3)
# helmetn262.jpg
# (152, 331, 3)
# helmetn263.jpg
# (700, 700, 3)
# helmetn264.jpg
# (540, 540, 3)
# helmetn265.jpg
# (242, 208, 3)
# helmetn266.jpg
# (800, 800, 3)
# helmetn267.jpg
# (500, 500, 3)
# helmetn268.jpg
# (540, 417, 3)
# helmetn269.jpg
# (275, 183, 3)
# helmetn27.jpg
# (238, 240, 3)
# helmetn270.jpg
# (300, 500, 3)
# helmetn271.jpg
# (1000, 1000, 3)
# helmetn272.jpg
# (700, 700, 3)
# helmetn273.jpg
# (215, 234, 3)
# helmetn274.jpg
# (513, 773, 3)
# helmetn275.jpg
# (600, 480, 3)
# helmetn276.jpg
# (320, 640, 3)
# helmetn277.jpg
# (700, 525, 3)
# helmetn278.jpg
# (770, 770, 3)
# helmetn279.jpg
# (647, 970, 3)
# helmetn28.jpg
# (238, 232, 3)
# helmetn280.jpg
# (237, 213, 3)
# helmetn281.jpg
# (583, 960, 3)
# helmetn282.jpg
# (600, 600, 3)
# helmetn283.jpg
# (550, 550, 3)
# helmetn284.jpg
# (183, 275, 3)
# helmetn285.jpg
# (165, 305, 3)
# helmetn286.jpg
# (208, 243, 3)
# helmetn287.jpg
# (278, 181, 3)
# helmetn288.jpg
# (320, 640, 3)
# helmetn289.jpg
# (720, 1280, 3)
# helmetn29.jpg
# (238, 234, 3)
# helmetn290.jpg
# (700, 525, 3)
# helmetn291.jpg
# (213, 237, 3)
# helmetn292.jpg
# (422, 395, 3)
# helmetn293.jpg
# (459, 401, 3)
# helmetn294.jpg
# (611, 698, 3)
# helmetn295.jpg
# (441, 402, 3)
# helmetn296.jpg
# (424, 394, 3)
# helmetn297.jpg
# (425, 409, 3)
# helmetn298.jpg
# (404, 426, 3)
# helmetn299.jpg
# (379, 374, 3)
# helmetn3.jpg
# (241, 238, 3)
# helmetn30.jpg
# (236, 238, 3)
# helmetn300.jpg
# (167, 301, 3)
# helmetn301.jpg
# (600, 600, 3)
# helmetn302.jpg
# (225, 225, 3)
# helmetn303.jpg
# (431, 422, 3)
# helmetn304.jpg
# (500, 500, 3)
# helmetn305.jpg
# (446, 420, 3)
# helmetn306.jpg
# (316, 309, 3)
# helmetn307.jpg
# (432, 408, 3)
# helmetn308.jpg
# (421, 418, 3)
# helmetn309.jpg
# (449, 427, 3)
# helmetn31.jpg
# (236, 240, 3)
# helmetn310.jpg
# (355, 334, 3)
# helmetn311.jpg
# (225, 225, 3)
# helmetn312.jpg
# (400, 400, 3)
# helmetn313.jpg
# (4000, 3000, 3)
# helmetn314.jpg
# (472, 411, 3)
# helmetn315.jpg
# (1255, 2230, 3)
# helmetn316.jpg
# (1133, 1500, 3)
# helmetn317.jpg
# (475, 654, 3)
# helmetn318.jpg
# (802, 800, 3)
# helmetn319.jpg
# (720, 720, 3)
# helmetn32.jpg
# (234, 240, 3)
# helmetn320.jpg
# (500, 500, 3)
# helmetn321.jpg
# (183, 275, 3)
# helmetn322.jpg
# (400, 400, 3)
# helmetn323.jpg
# (400, 600, 3)
# helmetn324.jpg
# (450, 428, 3)
# helmetn325.jpg
# (500, 500, 3)
# helmetn326.jpg
# (216, 337, 3)
# helmetn327.jpg
# (500, 500, 3)
# helmetn328.jpg
# (535, 660, 3)
# helmetn329.jpg
# (929, 1280, 3)
# helmetn33.jpg
# (234, 232, 3)
# helmetn330.jpg
# (400, 400, 3)
# helmetn331.jpg
# (854, 1280, 3)
# helmetn332.jpg
# (202, 249, 3)
# helmetn333.jpg
# (658, 580, 3)
# helmetn334.jpg
# (400, 400, 3)
# helmetn335.jpg
# (492, 428, 3)
# helmetn336.jpg
# (600, 600, 3)
# helmetn337.jpg
# (800, 800, 3)
# helmetn338.jpg
# (720, 720, 3)
# helmetn339.jpg
# (800, 800, 3)
# helmetn34.jpg
# (234, 234, 3)
# helmetn340.jpg
# (450, 460, 3)
# helmetn341.jpg
# (225, 225, 3)
# helmetn342.jpg
# (446, 411, 3)
# helmetn343.jpg
# (300, 300, 3)
# helmetn344.jpg
# (240, 300, 3)
# helmetn345.jpg
# (1200, 1200, 3)
# helmetn346.jpg
# (600, 900, 3)
# helmetn347.jpg
# (750, 750, 3)
# helmetn348.jpg
# (237, 213, 3)
# helmetn349.jpg
# (292, 292, 3)
# helmetn35.jpg
# (246, 232, 3)
# helmetn350.jpg
# (600, 600, 3)
# helmetn351.jpg
# (354, 630, 3)
# helmetn352.jpg
# (225, 225, 3)
# helmetn353.jpg
# (388, 378, 3)
# helmetn354.jpg
# (697, 697, 3)
# helmetn355.jpg
# (1300, 1300, 3)
# helmetn356.jpg
# (780, 780, 3)
# helmetn357.jpg
# (450, 315, 3)
# helmetn358.jpg
# (300, 300, 3)
# helmetn359.jpg
# (225, 225, 3)
# helmetn36.jpg
# (236, 240, 3)
# helmetn360.jpg
# (225, 225, 3)
# helmetn361.jpg
# (438, 658, 3)
# helmetn362.jpg
# (225, 225, 3)
# helmetn363.jpg
# (451, 412, 3)
# helmetn364.jpg
# (465, 620, 3)
# helmetn365.jpg
# (225, 225, 3)
# helmetn366.jpg
# (163, 310, 3)
# helmetn367.jpg
# (400, 400, 3)
# helmetn368.jpg
# (275, 183, 3)
# helmetn369.jpg
# (1300, 866, 3)
# helmetn37.jpg
# (236, 232, 3)
# helmetn370.jpg
# (1300, 867, 3)
# helmetn371.jpg
# (183, 275, 3)
# helmetn372.jpg
# (275, 183, 3)
# helmetn38.jpg
# (234, 238, 3)
# helmetn39.jpg
# (234, 240, 3)
# helmetn4.jpg
# (234, 240, 3)
# helmetn40.jpg
# (234, 234, 3)
# helmetn41.jpg
# (236, 240, 3)
# helmetn42.jpg
# (234, 238, 3)
# helmetn43.jpg
# (234, 240, 3)
# helmetn44.jpg
# (234, 232, 3)
# helmetn45.jpg
# (234, 234, 3)
# helmetn46.jpg
# (236, 234, 3)
# helmetn47.jpg
# (236, 238, 3)
# helmetn48.jpg
# (236, 232, 3)
# helmetn49.jpg
# (232, 240, 3)
# helmetn5.jpg
# (239, 238, 3)
# helmetn50.jpg
# (232, 240, 3)
# helmetn51.jpg
# (232, 234, 3)
# helmetn52.jpg
# (244, 240, 3)
# helmetn53.jpg
# (234, 238, 3)
# helmetn54.jpg
# (234, 240, 3)
# helmetn55.jpg
# (234, 232, 3)
# helmetn56.jpg
# (234, 234, 3)
# helmetn57.jpg
# (240, 238, 3)
# helmetn58.jpg
# (240, 240, 3)
# helmetn59.jpg
# (240, 232, 3)
# helmetn6.jpg
# (234, 232, 3)
# helmetn60.jpg
# (240, 234, 3)
# helmetn61.jpg
# (238, 238, 3)
# helmetn62.jpg
# (238, 240, 3)
# helmetn63.jpg
# (242, 238, 3)
# helmetn64.jpg
# (242, 240, 3)
# helmetn65.jpg
# (242, 240, 3)
# helmetn66.jpg
# (238, 232, 3)
# helmetn67.jpg
# (242, 234, 3)
# helmetn68.jpg
# (240, 240, 3)
# helmetn69.jpg
# (242, 238, 3)
# helmetn7.jpg
# (234, 234, 3)
# helmetn70.jpg
# (238, 240, 3)
# helmetn71.jpg
# (242, 240, 3)
# helmetn72.jpg
# (238, 232, 3)
# helmetn73.jpg
# (238, 234, 3)
# helmetn74.jpg
# (236, 238, 3)
# helmetn75.jpg
# (232, 240, 3)
# helmetn76.jpg
# (236, 240, 3)
# helmetn77.jpg
# (232, 232, 3)
# helmetn78.jpg
# (236, 234, 3)
# helmetn79.jpg
# (240, 240, 3)
# helmetn8.jpg
# (238, 238, 3)
# helmetn80.jpg
# (238, 238, 3)
# helmetn81.jpg
# (240, 240, 3)
# helmetn82.jpg
# (238, 240, 3)
# helmetn83.jpg
# (238, 232, 3)
# helmetn84.jpg
# (238, 234, 3)
# helmetn85.jpg
# (242, 238, 3)
# helmetn86.jpg
# (242, 240, 3)
# helmetn87.jpg
# (242, 240, 3)
# helmetn88.jpg
# (238, 232, 3)
# helmetn89.jpg
# (242, 234, 3)
# helmetn9.jpg
# (238, 240, 3)
# helmetn90.jpg
# (240, 242, 3)
# helmetn91.jpg
# (238, 238, 3)
# helmetn92.jpg
# (234, 240, 3)
# helmetn93.jpg
# (238, 240, 3)
# helmetn94.jpg
# (238, 232, 3)
# helmetn95.jpg
# (234, 234, 3)
# helmetn96.jpg
# (240, 238, 3)
# helmetn97.jpg
# (240, 240, 3)
# helmetn98.jpg
# (240, 240, 3)
# helmetn99.jpg
# (240, 232, 3)

# %%
for j in yes_list:
    print(j)
    img = cv2.imread('C:/K_digital/Source/helmet/helmet_y/' + j)
    print(img.shape)
# Out:
# helmety1.jpg
# (533, 400, 3)
# helmety10.jpg
# (194, 259, 3)
# helmety100.jpg
# (192, 262, 3)
# helmety101.jpg
# (507, 768, 3)
# helmety102.jpg
# (198, 255, 3)
# helmety103.jpg
# (1024, 768, 3)
# helmety104.jpg
# (168, 300, 3)
# helmety105.jpg
# (168, 300, 3)
# helmety106.jpg
# (284, 177, 3)
# helmety107.jpg
# (380, 570, 3)
# helmety108.jpg
# (183, 275, 3)
# helmety109.jpg
# (741, 620, 3)
# helmety11.jpg
# (225, 225, 3)
# helmety110.jpg
# (183, 275, 3)
# helmety111.jpg
# (183, 275, 3)
# helmety112.jpg
# (650, 600, 3)
# helmety113.jpg
# (183, 275, 3)
# helmety114.jpg
# (225, 225, 3)
# helmety115.jpg
# (168, 300, 3)
# helmety116.jpg
# (183, 275, 3)
# helmety117.jpg
# (168, 300, 3)
# helmety118.jpg
# (162, 311, 3)
# helmety119.jpg
# (183, 275, 3)
# helmety12.jpg
# (183, 275, 3)
# helmety120.jpg
# (168, 300, 3)
# helmety121.jpg
# (190, 265, 3)
# helmety122.jpg
# (183, 275, 3)
# helmety123.jpg
# (183, 275, 3)
# helmety124.jpg
# (720, 1280, 3)
# helmety125.jpg
# (162, 311, 3)
# helmety126.jpg
# (150, 335, 3)
# helmety127.jpg
# (275, 183, 3)
# helmety128.jpg
# (194, 259, 3)
# helmety129.jpg
# (181, 278, 3)
# helmety13.jpg
# (827, 620, 3)
# helmety130.jpg
# (194, 259, 3)
# helmety131.jpg
# (183, 275, 3)
# helmety132.jpg
# (282, 179, 3)
# helmety133.jpg
# (180, 280, 3)
# helmety134.jpg
# (190, 265, 3)
# helmety135.jpg
# (201, 251, 3)
# helmety136.jpg
# (192, 263, 3)
# helmety137.jpg
# (159, 318, 3)
# helmety138.jpg
# (191, 264, 3)
# helmety139.jpg
# (183, 275, 3)
# helmety14.jpg
# (225, 225, 3)
# helmety140.jpg
# (183, 275, 3)
# helmety141.jpg
# (184, 274, 3)
# helmety142.jpg
# (168, 300, 3)
# helmety143.jpg
# (252, 200, 3)
# helmety144.jpg
# (183, 275, 3)
# helmety145.jpg
# (183, 275, 3)
# helmety146.jpg
# (223, 226, 3)
# helmety147.jpg
# (194, 259, 3)
# helmety148.jpg
# (234, 323, 3)
# helmety149.jpg
# (540, 347, 3)
# helmety15.jpg
# (183, 275, 3)
# helmety150.jpg
# (234, 193, 3)
# helmety151.jpg
# (447, 640, 3)
# helmety152.jpg
# (371, 640, 3)
# helmety153.jpg
# (540, 347, 3)
# helmety154.jpg
# (500, 640, 3)
# helmety155.jpg
# (447, 640, 3)
# helmety156.jpg
# (540, 348, 3)
# helmety157.jpg
# (447, 640, 3)
# helmety158.jpg
# (540, 347, 3)
# helmety159.jpg
# (447, 640, 3)
# helmety16.jpg
# (225, 225, 3)
# helmety160.jpg
# (473, 640, 3)
# helmety161.jpg
# (540, 347, 3)
# helmety162.jpg
# (234, 230, 3)
# helmety163.jpg
# (540, 390, 3)
# helmety164.jpg
# (540, 389, 3)
# helmety165.jpg
# (540, 347, 3)
# helmety166.jpg
# (540, 347, 3)
# helmety167.jpg
# (540, 346, 3)
# helmety168.jpg
# (540, 370, 3)
# helmety169.jpg
# (406, 640, 3)
# helmety17.jpg
# (191, 264, 3)
# helmety170.jpg
# (447, 640, 3)
# helmety171.jpg
# (447, 640, 3)
# helmety172.jpg
# (434, 640, 3)
# helmety173.jpg
# (447, 640, 3)
# helmety174.jpg
# (234, 409, 3)
# helmety175.jpg
# (540, 375, 3)
# helmety176.jpg
# (540, 520, 3)
# helmety177.jpg
# (447, 640, 3)
# helmety178.jpg
# (540, 347, 3)
# helmety179.jpg
# (540, 357, 3)
# helmety18.jpg
# (512, 683, 3)
# helmety180.jpg
# (447, 640, 3)
# helmety181.jpg
# (447, 640, 3)
# helmety182.jpg
# (447, 640, 3)
# helmety183.jpg
# (447, 640, 3)
# helmety184.jpg
# (447, 640, 3)
# helmety185.jpg
# (447, 640, 3)
# helmety186.jpg
# (234, 299, 3)
# helmety187.jpg
# (447, 640, 3)
# helmety188.jpg
# (447, 640, 3)
# helmety189.jpg
# (447, 640, 3)
# helmety19.jpg
# (181, 278, 3)
# helmety190.jpg
# (540, 346, 3)
# helmety191.jpg
# (447, 640, 3)
# helmety192.jpg
# (540, 347, 3)
# helmety193.jpg
# (447, 640, 3)
# helmety194.jpg
# (540, 390, 3)
# helmety195.jpg
# (441, 640, 3)
# helmety196.jpg
# (540, 344, 3)
# helmety197.jpg
# (540, 347, 3)
# helmety198.jpg
# (237, 328, 3)
# helmety199.jpg
# (447, 640, 3)
# helmety2.jpg
# (180, 280, 3)
# helmety20.jpg
# (183, 275, 3)
# helmety200.jpg
# (540, 347, 3)
# helmety201.jpg
# (447, 640, 3)
# helmety202.jpg
# (447, 640, 3)
# helmety203.jpg
# (447, 640, 3)
# helmety204.jpg
# (447, 640, 3)
# helmety205.jpg
# (447, 640, 3)
# helmety206.jpg
# (447, 640, 3)
# helmety207.jpg
# (447, 640, 3)
# helmety208.jpg
# (233, 640, 3)
# helmety209.jpg
# (540, 388, 3)
# helmety21.jpg
# (182, 276, 3)
# helmety210.jpg
# (234, 339, 3)
# helmety211.jpg
# (447, 640, 3)
# helmety212.jpg
# (447, 640, 3)
# helmety213.jpg
# (540, 347, 3)
# helmety214.jpg
# (447, 640, 3)
# helmety215.jpg
# (447, 640, 3)
# helmety216.jpg
# (447, 640, 3)
# helmety217.jpg
# (540, 404, 3)
# helmety218.jpg
# (519, 640, 3)
# helmety219.jpg
# (540, 347, 3)
# helmety22.jpg
# (168, 300, 3)
# helmety220.jpg
# (447, 640, 3)
# helmety221.jpg
# (447, 640, 3)
# helmety222.jpg
# (234, 276, 3)
# helmety223.jpg
# (447, 640, 3)
# helmety224.jpg
# (447, 640, 3)
# helmety225.jpg
# (444, 640, 3)
# helmety226.jpg
# (447, 640, 3)
# helmety227.jpg
# (445, 640, 3)
# helmety228.jpg
# (447, 640, 3)
# helmety229.jpg
# (447, 640, 3)
# helmety23.jpg
# (209, 242, 3)
# helmety230.jpg
# (540, 347, 3)
# helmety231.jpg
# (445, 640, 3)
# helmety232.jpg
# (540, 347, 3)
# helmety233.jpg
# (447, 640, 3)
# helmety234.jpg
# (234, 341, 3)
# helmety235.jpg
# (540, 347, 3)
# helmety236.jpg
# (447, 640, 3)
# helmety237.jpg
# (540, 346, 3)
# helmety238.jpg
# (447, 640, 3)
# helmety239.jpg
# (447, 640, 3)
# helmety24.jpg
# (173, 291, 3)
# helmety240.jpg
# (447, 640, 3)
# helmety241.jpg
# (447, 640, 3)
# helmety242.jpg
# (447, 640, 3)
# helmety243.jpg
# (540, 347, 3)
# helmety244.jpg
# (447, 640, 3)
# helmety245.jpg
# (447, 640, 3)
# helmety246.jpg
# (234, 149, 3)
# helmety247.jpg
# (540, 347, 3)
# helmety248.jpg
# (234, 330, 3)
# helmety249.jpg
# (447, 640, 3)
# helmety25.jpg
# (183, 275, 3)
# helmety250.jpg
# (234, 211, 3)
# helmety251.jpg
# (540, 390, 3)
# helmety252.jpg
# (243, 162, 3)
# helmety253.jpg
# (447, 640, 3)
# helmety254.jpg
# (234, 205, 3)
# helmety255.jpg
# (447, 640, 3)
# helmety256.jpg
# (234, 351, 3)
# helmety257.jpg
# (444, 640, 3)
# helmety258.jpg
# (241, 362, 3)
# helmety259.jpg
# (447, 640, 3)
# helmety26.jpg
# (512, 512, 3)
# helmety260.jpg
# (234, 283, 3)
# helmety261.jpg
# (447, 640, 3)
# helmety262.jpg
# (234, 339, 3)
# helmety263.jpg
# (446, 640, 3)
# helmety264.jpg
# (243, 323, 3)
# helmety265.jpg
# (447, 640, 3)
# helmety266.jpg
# (243, 325, 3)
# helmety267.jpg
# (540, 356, 3)
# helmety268.jpg
# (234, 163, 3)
# helmety269.jpg
# (447, 640, 3)
# helmety27.jpg
# (288, 175, 3)
# helmety270.jpg
# (234, 313, 3)
# helmety271.jpg
# (447, 640, 3)
# helmety272.jpg
# (234, 317, 3)
# helmety273.jpg
# (540, 347, 3)
# helmety274.jpg
# (234, 391, 3)
# helmety275.jpg
# (540, 347, 3)
# helmety276.jpg
# (234, 391, 3)
# helmety277.jpg
# (540, 347, 3)
# helmety278.jpg
# (234, 391, 3)
# helmety279.jpg
# (540, 520, 3)
# helmety28.jpg
# (512, 512, 3)
# helmety280.jpg
# (234, 403, 3)
# helmety281.jpg
# (447, 640, 3)
# helmety282.jpg
# (234, 167, 3)
# helmety283.jpg
# (540, 347, 3)
# helmety284.jpg
# (234, 313, 3)
# helmety285.jpg
# (447, 640, 3)
# helmety286.jpg
# (234, 293, 3)
# helmety287.jpg
# (447, 640, 3)
# helmety288.jpg
# (234, 149, 3)
# helmety289.jpg
# (540, 390, 3)
# helmety29.jpg
# (340, 340, 3)
# helmety290.jpg
# (234, 235, 3)
# helmety291.jpg
# (447, 640, 3)
# helmety292.jpg
# (234, 305, 3)
# helmety293.jpg
# (447, 640, 3)
# helmety294.jpg
# (234, 243, 3)
# helmety295.jpg
# (540, 346, 3)
# helmety296.jpg
# (184, 275, 3)
# helmety297.jpg
# (447, 640, 3)
# helmety298.jpg
# (237, 150, 3)
# helmety299.jpg
# (447, 640, 3)
# helmety3.jpg
# (512, 768, 3)
# helmety30.jpg
# (323, 340, 3)
# helmety300.jpg
# (234, 391, 3)
# helmety301.jpg
# (447, 640, 3)
# helmety302.jpg
# (234, 165, 3)
# helmety303.jpg
# (447, 640, 3)
# helmety304.jpg
# (540, 346, 3)
# helmety305.jpg
# (447, 640, 3)
# helmety306.jpg
# (447, 640, 3)
# helmety307.jpg
# (447, 640, 3)
# helmety308.jpg
# (447, 640, 3)
# helmety309.jpg
# (447, 640, 3)
# helmety31.jpg
# (340, 340, 3)
# helmety310.jpg
# (234, 404, 3)
# helmety311.jpg
# (540, 347, 3)
# helmety312.jpg
# (430, 640, 3)
# helmety313.jpg
# (447, 640, 3)
# helmety314.jpg
# (540, 418, 3)
# helmety315.jpg
# (447, 640, 3)
# helmety316.jpg
# (540, 347, 3)
# helmety317.jpg
# (540, 344, 3)
# helmety318.jpg
# (447, 640, 3)
# helmety319.jpg
# (447, 640, 3)
# helmety32.jpg
# (454, 340, 3)
# helmety320.jpg
# (447, 640, 3)
# helmety321.jpg
# (213, 321, 3)
# helmety322.jpg
# (540, 347, 3)
# helmety323.jpg
# (447, 640, 3)
# helmety324.jpg
# (447, 640, 3)
# helmety325.jpg
# (409, 640, 3)
# helmety326.jpg
# (501, 640, 3)
# helmety327.jpg
# (430, 640, 3)
# helmety328.jpg
# (460, 640, 3)
# helmety329.jpg
# (405, 640, 3)
# helmety33.jpg
# (524, 340, 3)
# helmety330.jpg
# (540, 345, 3)
# helmety331.jpg
# (447, 640, 3)
# helmety332.jpg
# (447, 640, 3)
# helmety333.jpg
# (234, 149, 3)
# helmety334.jpg
# (447, 640, 3)
# helmety335.jpg
# (540, 347, 3)
# helmety336.jpg
# (538, 640, 3)
# helmety337.jpg
# (540, 347, 3)
# helmety338.jpg
# (447, 640, 3)
# helmety339.jpg
# (447, 640, 3)
# helmety34.jpg
# (512, 512, 3)
# helmety340.jpg
# (540, 347, 3)
# helmety341.jpg
# (447, 640, 3)
# helmety342.jpg
# (447, 640, 3)
# helmety343.jpg
# (540, 281, 3)
# helmety344.jpg
# (447, 640, 3)
# helmety345.jpg
# (226, 393, 3)
# helmety346.jpg
# (540, 347, 3)
# helmety347.jpg
# (447, 640, 3)
# helmety348.jpg
# (447, 640, 3)
# helmety349.jpg
# (447, 640, 3)
# helmety35.jpg
# (340, 340, 3)
# helmety350.jpg
# (447, 640, 3)
# helmety351.jpg
# (447, 640, 3)
# helmety352.jpg
# (447, 640, 3)
# helmety353.jpg
# (540, 617, 3)
# helmety354.jpg
# (447, 640, 3)
# helmety355.jpg
# (447, 640, 3)
# helmety356.jpg
# (447, 640, 3)
# helmety357.jpg
# (237, 356, 3)
# helmety358.jpg
# (540, 347, 3)
# helmety359.jpg
# (540, 347, 3)
# helmety36.jpg
# (453, 340, 3)
# helmety360.jpg
# (540, 345, 3)
# helmety361.jpg
# (540, 347, 3)
# helmety362.jpg
# (447, 640, 3)
# helmety363.jpg
# (540, 347, 3)
# helmety364.jpg
# (447, 640, 3)
# helmety365.jpg
# (461, 640, 3)
# helmety366.jpg
# (540, 347, 3)
# helmety367.jpg
# (447, 640, 3)
# helmety368.jpg
# (447, 640, 3)
# helmety37.jpg
# (510, 340, 3)
# helmety38.jpg
# (600, 340, 3)
# helmety39.jpg
# (453, 340, 3)
# helmety4.jpg
# (183, 275, 3)
# helmety40.jpg
# (227, 340, 3)
# helmety41.jpg
# (510, 340, 3)
# helmety42.jpg
# (453, 340, 3)
# helmety43.jpg
# (434, 340, 3)
# helmety44.jpg
# (512, 683, 3)
# helmety45.jpg
# (512, 683, 3)
# helmety46.jpg
# (692, 620, 3)
# helmety47.jpg
# (512, 512, 3)
# helmety48.jpg
# (832, 406, 3)
# helmety49.jpg
# (512, 512, 3)
# helmety5.jpg
# (183, 275, 3)
# helmety50.jpg
# (803, 620, 3)
# helmety51.jpg
# (512, 865, 3)
# helmety52.jpg
# (826, 620, 3)
# helmety53.jpg
# (512, 678, 3)
# helmety54.jpg
# (827, 620, 3)
# helmety55.jpg
# (827, 620, 3)
# helmety56.jpg
# (512, 512, 3)
# helmety57.jpg
# (183, 275, 3)
# helmety58.jpg
# (408, 612, 3)
# helmety59.jpg
# (183, 275, 3)
# helmety6.jpg
# (183, 275, 3)
# helmety60.jpg
# (225, 225, 3)
# helmety61.jpg
# (195, 259, 3)
# helmety62.jpg
# (245, 205, 3)
# helmety63.jpg
# (1667, 2500, 3)
# helmety64.jpg
# (174, 290, 3)
# helmety65.jpg
# (251, 201, 3)
# helmety66.jpg
# (826, 620, 3)
# helmety67.jpg
# (750, 1000, 3)
# helmety68.jpg
# (183, 275, 3)
# helmety69.jpg
# (352, 626, 3)
# helmety7.jpg
# (168, 300, 3)
# helmety70.jpg
# (860, 860, 3)
# helmety71.jpg
# (225, 225, 3)
# helmety72.jpg
# (800, 1260, 3)
# helmety73.jpg
# (574, 574, 3)
# helmety74.jpg
# (225, 225, 3)
# helmety75.jpg
# (194, 259, 3)
# helmety76.jpg
# (338, 600, 3)
# helmety77.jpg
# (827, 620, 3)
# helmety78.jpg
# (251, 201, 3)
# helmety79.jpg
# (225, 225, 3)
# helmety8.jpg
# (185, 272, 3)
# helmety80.jpg
# (183, 275, 3)
# helmety81.jpg
# (181, 278, 3)
# helmety82.jpg
# (183, 275, 3)
# helmety83.jpg
# (540, 960, 3)
# helmety84.jpg
# (183, 275, 3)
# helmety85.jpg
# (408, 612, 3)
# helmety86.jpg
# (183, 275, 3)
# helmety87.jpg
# (827, 620, 3)
# helmety88.jpg
# (667, 1000, 3)
# helmety89.jpg
# (667, 1000, 3)
# helmety9.jpg
# (185, 272, 3)
# helmety90.jpg
# (177, 285, 3)
# helmety91.jpg
# (333, 500, 3)
# helmety92.jpg
# (173, 292, 3)
# helmety93.jpg
# (183, 275, 3)
# helmety94.jpg
# (640, 960, 3)
# helmety95.jpg
# (667, 1000, 3)
# helmety96.jpg
# (183, 275, 3)
# helmety97.jpg
# (853, 640, 3)
# helmety98.jpg
# (512, 768, 3)
# helmety99.jpg
# (183, 275, 3)

# %%
w = []
h = []

for i in non_list:
    img =  cv2.imread('C:/K_digital/Source/helmet/helmet_n/' + i)
    h.append(img.shape[0])
    w.append(img.shape[1])

for j in yes_list:
    img = cv2.imread('C:/K_digital/Source/helmet/helmet_y/' + j)
    h.append(img.shape[0])
    w.append(img.shape[1])

# %%
import tensorflow as tf
import keras
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.utils import load_img
img_w, img_h = 140, 180
images = [] #실제 데이터 
labels = [] #정답 데이터(1,0으로 분류)

for i in non_list:
    image = load_img('C:/K_digital/Source/helmet/helmet_n/' + i, target_size=(img_w, img_h))
    image = img_to_array(image)
    images.append(image)
    labels.append(0)#헬멧 쓰지 않았으므로 0
    
for j in yes_list:
    image = load_img('C:/K_digital/Source/helmet/helmet_y/' + j, target_size=(img_w, img_h))
    image = img_to_array(image)
    images.append(image)
    labels.append(1)#헬멧 썼기 때문에 1

images[0].shape
images[1].shape
#(140, 180, 3)
# Out:
# C:\Anaconda3\lib\site-packages\PIL\Image.py:959: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# (140, 180, 3)

# %%
images[1].shape
# Out:
# (140, 180, 3)

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
 

    
path_dir1 = 'C:/K_digital/Source/helmet/helmet_n/'
path_dir2 = 'C:/K_digital/Source/helmet/helmet_y/'
 
file_list1 = os.listdir(path_dir1) # path에 존재하는 파일 목록 가져오기
file_list2 = os.listdir(path_dir2)
 
file_list1_num = len(file_list1)
file_list2_num = len(file_list2)
 
file_num = file_list1_num + file_list2_num
 

#%% 이미지 전처리
num = 0;
all_img = np.float32(np.zeros((file_num, 224, 224, 3))) 
all_label = np.float64(np.zeros((file_num, 1)))
 
for img_name in file_list1:
    img_path = path_dir1+img_name
    img = load_img(img_path, target_size=(224, 224))
    
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    all_img[num, :, :, :] = x
    
    all_label[num] = 0 # nomask
    num = num + 1

for img_name in file_list2:
    img_path = path_dir2+img_name
    img = load_img(img_path, target_size=(224, 224))
    
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    all_img[num, :, :, :] = x
    
    all_label[num] = 1 # mask
    num = num + 1
 
 
# 데이터셋 섞기(적절하게 훈련되게 하기 위함) 
n_elem = all_label.shape[0]
indices = np.random.choice(n_elem, size=n_elem, replace=False)
 
all_label = all_label[indices]
all_img = all_img[indices]
 
# 훈련셋 테스트셋 분할
num_train = int(np.round(all_label.shape[0]*0.8))
num_test = int(np.round(all_label.shape[0]*0.2))
 
train_img = all_img[0:num_train, :, :, :]
test_img = all_img[num_train:, :, :, :] 
 
train_label = all_label[0:num_train]
test_label = all_label[num_train:]
 
 
 
#%% 
# create the base pre-trained model
IMG_SHAPE = (224, 224, 3)
 
base_model = ResNet50(input_shape=IMG_SHAPE, weights='imagenet', include_top=False)
base_model.trainable = False
base_model.summary()
print("Number of layers in the base model: ", len(base_model.layers))
 
flatten_layer = Flatten()
dense_layer1 = Dense(128, activation='relu')
bn_layer1 = BatchNormalization()
dense_layer2 = Dense(1, activation=tf.nn.sigmoid)
 
model = Sequential([
        base_model,
        flatten_layer,
        dense_layer1,
        bn_layer1,
        dense_layer2,
        ])
 
base_learning_rate = 0.001
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()
 
history = model.fit(train_img, train_label, epochs=10, batch_size=16, validation_data = (test_img, test_label))
 
# save model
model.save("model.h5")
 
print("Saved model to disk")
# Out:
# C:\Anaconda3\lib\site-packages\PIL\Image.py:959: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________
# Number of layers in the base model:  175
# WARNING:absl:`lr` is deprecated, please use `learning_rate` instead, or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 128)               12845184
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 36,433,537
# Trainable params: 12,845,569
# Non-trainable params: 23,587,968
# _________________________________________________________________
# Epoch 1/10
# 37/37 [==============================] - 50s 1s/step - loss: 0.2199 - accuracy: 0.9223 - val_loss: 0.2703 - val_accuracy: 0.9662
# Epoch 2/10
# 37/37 [==============================] - 51s 1s/step - loss: 0.0271 - accuracy: 0.9949 - val_loss: 0.1536 - val_accuracy: 0.9730
# Epoch 3/10
# 37/37 [==============================] - 48s 1s/step - loss: 0.0221 - accuracy: 0.9966 - val_loss: 0.1117 - val_accuracy: 0.9797
# Epoch 4/10
# 37/37 [==============================] - 52s 1s/step - loss: 0.0123 - accuracy: 0.9949 - val_loss: 0.1035 - val_accuracy: 0.9797
# Epoch 5/10
# 37/37 [==============================] - 52s 1s/step - loss: 0.0130 - accuracy: 0.9949 - val_loss: 0.0969 - val_accuracy: 0.9662
# Epoch 6/10
# 37/37 [==============================] - 54s 1s/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.0727 - val_accuracy: 0.9730
# Epoch 7/10
# 37/37 [==============================] - 53s 1s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9730
# Epoch 8/10
# 37/37 [==============================] - 53s 1s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9797
# Epoch 9/10
# 37/37 [==============================] - 54s 1s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9865
# Epoch 10/10
# 37/37 [==============================] - 55s 1s/step - loss: 0.0119 - accuracy: 0.9932 - val_loss: 0.0863 - val_accuracy: 0.9730
# Saved model to disk

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'g', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
# import necessary packages
import cvlib as cv
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing.image import img_to_array
from PIL import ImageFont, ImageDraw, Image
 

model = load_model('model.h5')
model.summary()
 
# open webcam
webcam = cv2.VideoCapture(0)
 

if not webcam.isOpened():
    print("Could not open webcam")
    exit()
    

# loop through frames
while webcam.isOpened():
 
    # read frame from webcam 
    status, frame = webcam.read()
    
    if not status:
        print("Could not read frame")
        exit()
 
    # apply face detection
    face, confidence = cv.detect_face(frame)
 
    # loop through detected faces
    for idx, f in enumerate(face):
        
        (startX, startY) = f[0], f[1]
        (endX, endY) = f[2], f[3]
        
        if 0 <= startX <= frame.shape[1] and 0 <= endX <= frame.shape[1] and 0 <= startY <= frame.shape[0] and 0 <= endY <= frame.shape[0]:
            
            face_region = frame[startY:endY, startX:endX]
            
            face_region1 = cv2.resize(face_region, (224, 224), interpolation = cv2.INTER_AREA)
            
            x = img_to_array(face_region1)
            x = np.expand_dims(x, axis=0)
            x = preprocess_input(x)
            
            prediction = model.predict(x)
 
            if prediction < 0.5: # 헬멧 미착용으로 판별되면, 
                cv2.rectangle(frame, (startX,startY), (endX,endY), (0,0,255), 2)
                Y = startY - 10 if startY - 10 > 10 else startY + 10
                text = "Helmet X ({:.2f}%)".format((1 - prediction[0][0])*100)
                cv2.putText(frame, text, (startX,Y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
                
            else: # 헬멧착용으로 판별되면
                cv2.rectangle(frame, (startX,startY), (endX,endY), (0,255,0), 2)
                Y = startY - 10 if startY - 10 > 10 else startY + 10
                text = "Helmet O ({:.2f}%)".format(prediction[0][0]*100)
                cv2.putText(frame, text, (startX,Y), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 2)
                
    # display output
    cv2.imshow("Helmet classify", frame)
 
    # press "Q" to stop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
# release resources
webcam.release()
cv2.destroyAllWindows()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 7, 7, 2048)        23587712
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dense (Dense)               (None, 128)               12845184
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 36,433,537
# Trainable params: 12,845,569
# Non-trainable params: 23,587,968
# _________________________________________________________________
# 1/1 [==============================] - 1s 864ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 122ms/step
